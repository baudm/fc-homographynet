# %%
# %matplotlib inline

# %%
import os.path
import glob
import numpy as np
import matplotlib.pyplot as plt
import cv2

# %%
path = 'output/61529231-fd89-4c00-951a-a1e7af94e239.npz'

# %%
print('path:', os.path.abspath(path))
# Out:
# path: /Users/richard/MSEE/MSCOCO/output/61529231-fd89-4c00-951a-a1e7af94e239.npz

# %%
archive = np.load(os.path.abspath(path))
print('keys:', archive.files)
# Out:
# keys: ['images', 'corners', 'imageA']

# %%
images = archive['images']
corners = archive['corners']
imageA = archive['imageA']

print('images.shape: ', images.shape)
print('corners.shape: ', corners.shape)
print('imageA.shape: ', imageA.shape)
# Out:
# images.shape:  (32, 128, 128, 2)
# corners.shape:  (32, 4, 2)
# imageA.shape:  (32, 240, 320)

# %%
idx = 4

# %%
sample_image = np.split(images[idx], 2, axis=-1)

# %%
plt.imshow(sample_image[0].squeeze(), cmap='gray')

# %%
plt.imshow(sample_image[1].squeeze(), cmap='gray')

# %%
sample_corner = corners[idx]
print('sample corner: ', sample_corner)
# Out:
# sample corner:  [[ 78  56]
#  [206  56]
#  [206 184]
#  [ 78 184]]

# %%
#img = cv2.imread('sample2017/' + filenames[0], cv2.IMREAD_GRAYSCALE)
img = imageA[idx]

# %%
pts = sample_corner.reshape(-1,1,2)
imgColor = cv2.cvtColor(img, cv2.COLOR_GRAY2BGR)
img2 = cv2.polylines(imgColor, [pts], True, (0,255,0))

# %%
plt.imshow(img2)
